# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import pandas as pd

# %%
#Creatimg my dataframe with column names scraped beforehand
df= pd.DataFrame(columns=['Rank',
 'Season',
 'Date',
 'Score',
 'Excitment',
 'Tension',
 'Comeback',
 'MVP',
 'LVP'])

# %%
start_date = datetime(2025, 10, 21)
end_date = datetime(2026, 1, 13)

current_date = start_date
while current_date <= end_date:
    #print(current_date.strftime("%Y-%m-%d"))  # or just use current_date
    url= f"https://stats.inpredictable.com/nba/topGame.php?sort=ei&season=2025&team=ALL&po=0&frdt={current_date.strftime('%Y-%m-%d')}&todt={current_date.strftime('%Y-%m-%d')}"
    page= requests.get(url)
    soup= BeautifulSoup(page.text, 'html')

    table= soup.find('table')

    ##Getting columns
    columns= soup.find_all('th')
    columns_list= [column.text for column in columns]

    #getting rows
    rows= table.find_all('tr')[1:]

    rows_list=[]
    for row in rows:
        curr= row.find_all('td')
        curr.pop(4)
        rows_list.append([data.text for data in curr])

    for row in rows_list:
        df.loc[len(df)]= row

    current_date += timedelta(days=1)

df.drop(['Rank'], axis=1, inplace=True)
df
# Out:
#     Season        Date             Score Excitment Tension Comeback  \
# 0     2025  2025-10-21  HOU 124, OKC 125      15.3    89.3      7.8
# 1     2025  2025-10-21  GSW 119, LAL 109       5.1    71.0      1.2
# 2     2025  2025-10-22  MIA 121, ORL 125      10.3    91.6      9.3
# 3     2025  2025-10-22  MIN 118, POR 114       9.9    91.8      6.2
# 4     2025  2025-10-22  PHI 117, BOS 116       9.5    83.7     23.3
# ..     ...         ...               ...       ...     ...      ...
# 569   2025  2026-01-13  CHI 113, HOU 119       8.4    93.7      1.6
# 570   2025  2026-01-13   SAS 98, OKC 119       4.4    68.9      1.4
# 571   2025  2026-01-13  ATL 116, LAL 141       2.9    47.3      1.5
# 572   2025  2026-01-13   POR 97, GSW 119       2.6    41.0      1.0
# 573   2025  2026-01-13  MIN 139, MIL 106       1.8    29.3      1.0
#
#                                MVP                   LVP
# 0    S. Gilgeous-Alexander: +85.0%   R. Sheppard: -32.2%
# 1                L. Don?i?: +20.0%      D. Ayton: -11.1%
# 2               A. Wiggins: +24.8%    B. Adebayo: -26.2%
# 3               A. Edwards: +42.3%    J. Holiday: -26.1%
# 4                 T. Maxey: +45.9%     S. Hauser: -17.2%
# ..                             ...                   ...
# 569               T. Jones: +47.7%   P. Williams: -14.5%
# 570  S. Gilgeous-Alexander: +15.1%      H. Barnes: -8.2%
# 571              L. Don?i?: +13.6%     J. Johnson: -7.8%
# 572          J. Butler III: +10.3%     J. Holiday: -5.3%
# 573           J. McDaniels: +13.3%  K. Porter Jr.: -4.3%
#
# [574 rows x 8 columns]

# %%
df.to_csv("2025_GEI_scraped.csv", index=False)
