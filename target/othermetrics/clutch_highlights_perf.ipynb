# %%
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
from nba_api.stats.endpoints import playbyplayv3
from nba_api.stats.endpoints import BoxScoreTraditionalV3
import time
import random
from requests.exceptions import ReadTimeout, ConnectionError, RequestException, Timeout
from json.decoder import JSONDecodeError
import re

def is_int_convertible(x):
    try:
        int(x)
        return True
    except (ValueError, TypeError):
        return False

def get_minutes_from_v3_clock(clock_str):
    if not isinstance(clock_str, str): return 0

    # Check for PTxxM format
    match = re.search(r'PT(\d+)M', clock_str)
    if match:
        return int(match.group(1))

    # Check for MM:SS format
    if ':' in clock_str:
        return int(clock_str.split(':')[0])

    return 0

# It will keep trying until it succeeds or you manually stop it.
def robust_fetch(endpoint_class, **kwargs):
    max_retries = 20  # High number, effectively infinite for short hiccups
    base_delay = 2    # Start waiting 2 seconds

    for attempt in range(max_retries):
        try:
            # Attempt the API call
            endpoint = endpoint_class(**kwargs)
            # Force a data access to ensure the request actually finished
            return endpoint.get_data_frames()[0]

        except (ReadTimeout, ConnectionError, Timeout, RequestException, JSONDecodeError) as e:
            # If any network/server error occurs:
            print(f"  [!] API Error on attempt {attempt+1}: {e}")
            print(f"  [i] Retrying in {base_delay} seconds...")

            time.sleep(base_delay)

            # Exponential Backoff: Wait longer next time (2s -> 4s -> 8s...)
            # Cap at 60 seconds to avoid waiting forever
            base_delay = min(base_delay * 2, 60)

        except Exception as e:
            # Catch unexpected Python errors (like syntax inside the API lib)
            print(f"  [!!!] Critical Unknown Error: {e}")
            break # Break so you don't infinite loop on a code bug

    return None # Return None if we completely failed after 20 tries

# %%
##.............data structures to be used.........##

#list of dictionary to append scraped data progressively
df_list=[] #every dict in this list represents a game

df= pd.DataFrame(columns=['GAME_ID',
                          'TEAM1',
                          'TEAM2', 'DATE', 'PF', 'CLUTCH', 'HIGHLIGHTS', 'PERFORMANCE'])

# %%
##.............Get data on Regular season games.........##
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable='2023-24',
                                              league_id_nullable='00',
                                              season_type_nullable='Regular Season')
games = gamefinder.get_data_frames()[0]
game_ids = games['GAME_ID'].unique().tolist() # get a list of distinct game_ids

# %%
print(f"Starting ingestion for {len(game_ids)} games...")

for i, game in enumerate(game_ids[962:], start=962):
    print(f"Processing Game {i + 1}/{len(game_ids)}: ID {game}")  # Progress indicator

    game_dict = {}

    try:
        game_dict['GAME_ID'] = game
        game_dict['TEAM1'] = str(games[games["GAME_ID"] == game].iloc[0]["TEAM_ABBREVIATION"])
        game_dict['TEAM2'] = str(games[games["GAME_ID"] == game].iloc[1]["TEAM_ABBREVIATION"])
        game_dict['DATE'] = str(games[games["GAME_ID"] == game].iloc[0]["GAME_DATE"])
        game_dict['PF'] = games[games["GAME_ID"] == game].iloc[0]["PF"] + games[games["GAME_ID"] == game].iloc[1]["PF"]

        #Fetch PlayByPlay
        pbp = robust_fetch(playbyplayv3.PlayByPlayV3, game_id=game)

        if pbp is None:
            print(f"  [x] Failed to fetch PBP for {game}. Skipping.")
            continue

        # --- A. Clutch Calculation ---
        period = pbp['period'].unique().max()
        if period == 5:
            game_dict['CLUTCH'] = 0.95
        elif period >= 6:
            game_dict['CLUTCH'] = 1.0
        else:
            #           Filter for 4th quarter +
            pbp_valid = pbp[pbp['period'] >= 4].copy()

            # Filter for last 5 minutes using helper (We apply the function to the 'clock' column)
            pbp_valid['MINUTES_REMAINING'] = pbp_valid['clock'].apply(get_minutes_from_v3_clock)
            pbp_valid = pbp_valid[pbp_valid['MINUTES_REMAINING'] < 5]

            # Calculate Margin Manually (Home - Away), Ensure we treat by forward fill if needed
            pbp_valid['scoreHome'] = pd.to_numeric(pbp_valid['scoreHome'], errors='coerce')
            pbp_valid['scoreAway'] = pd.to_numeric(pbp_valid['scoreAway'], errors='coerce')

            pbp_valid[['scoreHome', 'scoreAway']] = pbp_valid[['scoreHome', 'scoreAway']].ffill()
            pbp_valid = pbp_valid.dropna(subset=['scoreHome', 'scoreAway'])

            pbp_valid['margin'] = pbp_valid['scoreHome'] - pbp_valid['scoreAway']

            # Count possessions within +/- 5 points
            clutch_mask = (pbp_valid['margin'] <= 5) & (pbp_valid['margin'] >= -5)
            clutch_count = clutch_mask.sum()

            game_dict['CLUTCH'] = clutch_count

        # --- B. Performance Calculation ---
        stats_df = robust_fetch(BoxScoreTraditionalV3, game_id=game)

        if stats_df is None:
            print(f"  [x] Failed to fetch BoxScore for {game}. Skipping.")
            continue

        stats_df['GAME_SCORE'] = (
                stats_df['points'] + 0.4 * stats_df['fieldGoalsMade'] - 0.7 * stats_df['fieldGoalsAttempted'] -
                0.4 * (stats_df['freeThrowsAttempted'] - stats_df['freeThrowsMade']) + 0.7 * stats_df[
                    'reboundsOffensive'] +
                0.3 * stats_df['reboundsDefensive'] + stats_df['steals'] + 0.7 * stats_df['assists'] +
                0.7 * stats_df['blocks'] - 0.4 * stats_df['foulsPersonal'] - stats_df['turnovers']
        )

        performance_sum = 0.0
        for gs in stats_df['GAME_SCORE']:
            if gs >= 60.0:
                performance_sum += 0.95
            elif gs >= 50.0:
                performance_sum += 0.9
            elif gs >= 40.0:
                performance_sum += 0.8
            elif gs >= 30.0:
                performance_sum += 0.7

        game_dict['PERFORMANCE'] = performance_sum

        # --- C. Highlights Calculation ---
        pbp['description'] = pbp['description'].astype(str).str.upper()

        # Dunks: look for 'DUNK' in the single description column
        # Filter out 'MISS' to be safe, though usually 'Dunk' implies made in text
        if 'shotResult' in pbp.columns:
            dunks = pbp[
                (pbp['description'].str.contains("DUNK", case=False)) &
                (pbp['shotResult'] == 'Made')
                ].shape[0]
        else:
            # Fallback if specific column is missing
            dunks = pbp[
                (pbp['description'].str.contains("DUNK", case=False)) &
                (~pbp['description'].str.contains("MISS", case=False))
                ].shape[0]

        # Fix for threes: ensure we grab values safely
        threes = int(games[games["GAME_ID"] == game].iloc[0]["FG3M"] + games[games["GAME_ID"] == game].iloc[1]["FG3M"])

        blocks = int(games[games["GAME_ID"] == game].iloc[0]["BLK"] + games[games["GAME_ID"] == game].iloc[1]["BLK"])

        #calculate highlights/minutes
        total_highlights = dunks + (0.75 * threes) + blocks
        highlights_density = total_highlights / 48

        game_dict['HIGHLIGHTS'] = highlights_density

        df_list.append(game_dict)

        # Standard sleep
        time.sleep(random.uniform(0.5, 1.0))

    except Exception as e:
        print(f"  [!!!] Critical Error processing game {game}: {e}")
        # We continue to the next game even if this one crashes logic
        continue
# Out:
# Starting ingestion for 1230 games...
# Processing Game 963/1230: ID 0022300273

# %%
len(df_list)
# Out:
# 962

# %%
df_list
# Out:
# [{'GAME_ID': '0022301192',
#   'TEAM1': 'PHI',
#   'TEAM2': 'BKN',
#   'DATE': '2024-04-14',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7135416666666666},
#  {'GAME_ID': '0022301197',
#   'TEAM1': 'SAS',
#   'TEAM2': 'DET',
#   'DATE': '2024-04-14',
#   'PF': 26,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6927083333333334},
#  {'GAME_ID': '0022301190',
#   'TEAM1': 'NYK',
#   'TEAM2': 'CHI',
#   'DATE': '2024-04-14',
#   'PF': 38,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.625},
#  {'GAME_ID': '0022301194',
#   'TEAM1': 'PHX',
#   'TEAM2': 'MIN',
#   'DATE': '2024-04-14',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7239583333333334},
#  {'GAME_ID': '0022301199',
#   'TEAM1': 'LAC',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-14',
#   'PF': 27,
#   'CLUTCH': 27,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0677083333333333},
#  {'GAME_ID': '0022301186',
#   'TEAM1': 'WAS',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-14',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 1.09375},
#  {'GAME_ID': '0022301196',
#   'TEAM1': 'OKC',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-14',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301193',
#   'TEAM1': 'DEN',
#   'TEAM2': 'MEM',
#   'DATE': '2024-04-14',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6041666666666666},
#  {'GAME_ID': '0022301200',
#   'TEAM1': 'SAC',
#   'TEAM2': 'POR',
#   'DATE': '2024-04-14',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6041666666666666},
#  {'GAME_ID': '0022301195',
#   'TEAM1': 'NOP',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-14',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7604166666666666},
#  {'GAME_ID': '0022301188',
#   'TEAM1': 'ATL',
#   'TEAM2': 'IND',
#   'DATE': '2024-04-14',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.984375},
#  {'GAME_ID': '0022301198',
#   'TEAM1': 'UTA',
#   'TEAM2': 'GSW',
#   'DATE': '2024-04-14',
#   'PF': 34,
#   'CLUTCH': 37,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301189',
#   'TEAM1': 'MIA',
#   'TEAM2': 'TOR',
#   'DATE': '2024-04-14',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022301191',
#   'TEAM1': 'ORL',
#   'TEAM2': 'MIL',
#   'DATE': '2024-04-14',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022301187',
#   'TEAM1': 'CHA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-04-14',
#   'PF': 19,
#   'CLUTCH': 24,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.984375},
#  {'GAME_ID': '0022301172',
#   'TEAM1': 'WAS',
#   'TEAM2': 'CHI',
#   'DATE': '2024-04-12',
#   'PF': 47,
#   'CLUTCH': 62,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8541666666666666},
#  {'GAME_ID': '0022301182',
#   'TEAM1': 'NOP',
#   'TEAM2': 'GSW',
#   'DATE': '2024-04-12',
#   'PF': 28,
#   'CLUTCH': 27,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8489583333333334},
#  {'GAME_ID': '0022301176',
#   'TEAM1': 'MIA',
#   'TEAM2': 'TOR',
#   'DATE': '2024-04-12',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6510416666666666},
#  {'GAME_ID': '0022301181',
#   'TEAM1': 'DAL',
#   'TEAM2': 'DET',
#   'DATE': '2024-04-12',
#   'PF': 19,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022301174',
#   'TEAM1': 'CLE',
#   'TEAM2': 'IND',
#   'DATE': '2024-04-12',
#   'PF': 31,
#   'CLUTCH': 43,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.65625},
#  {'GAME_ID': '0022301177',
#   'TEAM1': 'MEM',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-12',
#   'PF': 44,
#   'CLUTCH': 62,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8854166666666666},
#  {'GAME_ID': '0022301180',
#   'TEAM1': 'DEN',
#   'TEAM2': 'SAS',
#   'DATE': '2024-04-12',
#   'PF': 32,
#   'CLUTCH': 30,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8958333333333334},
#  {'GAME_ID': '0022301185',
#   'TEAM1': 'SAC',
#   'TEAM2': 'PHX',
#   'DATE': '2024-04-12',
#   'PF': 35,
#   'CLUTCH': 56,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6770833333333334},
#  {'GAME_ID': '0022301183',
#   'TEAM1': 'POR',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-12',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022301179',
#   'TEAM1': 'MIL',
#   'TEAM2': 'OKC',
#   'DATE': '2024-04-12',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7291666666666666},
#  {'GAME_ID': '0022301175',
#   'TEAM1': 'BKN',
#   'TEAM2': 'NYK',
#   'DATE': '2024-04-12',
#   'PF': 34,
#   'CLUTCH': 55,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022301178',
#   'TEAM1': 'MIN',
#   'TEAM2': 'ATL',
#   'DATE': '2024-04-12',
#   'PF': 47,
#   'CLUTCH': 69,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8385416666666666},
#  {'GAME_ID': '0022301171',
#   'TEAM1': 'PHI',
#   'TEAM2': 'ORL',
#   'DATE': '2024-04-12',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301184',
#   'TEAM1': 'UTA',
#   'TEAM2': 'LAC',
#   'DATE': '2024-04-12',
#   'PF': 31,
#   'CLUTCH': 46,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301173',
#   'TEAM1': 'BOS',
#   'TEAM2': 'CHA',
#   'DATE': '2024-04-12',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.890625},
#  {'GAME_ID': '0022301167',
#   'TEAM1': 'NYK',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-11',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.09375},
#  {'GAME_ID': '0022301166',
#   'TEAM1': 'DET',
#   'TEAM2': 'CHI',
#   'DATE': '2024-04-11',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022301168',
#   'TEAM1': 'UTA',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-11',
#   'PF': 38,
#   'CLUTCH': 65,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9427083333333334},
#  {'GAME_ID': '0022301170',
#   'TEAM1': 'SAC',
#   'TEAM2': 'NOP',
#   'DATE': '2024-04-11',
#   'PF': 33,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301169',
#   'TEAM1': 'POR',
#   'TEAM2': 'GSW',
#   'DATE': '2024-04-11',
#   'PF': 36,
#   'CLUTCH': 10,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301164',
#   'TEAM1': 'DEN',
#   'TEAM2': 'MIN',
#   'DATE': '2024-04-10',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8958333333333334},
#  {'GAME_ID': '0022301163',
#   'TEAM1': 'SAS',
#   'TEAM2': 'OKC',
#   'DATE': '2024-04-10',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7239583333333334},
#  {'GAME_ID': '0022301165',
#   'TEAM1': 'PHX',
#   'TEAM2': 'LAC',
#   'DATE': '2024-04-10',
#   'PF': 26,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8229166666666666},
#  {'GAME_ID': '0022301160',
#   'TEAM1': 'BKN',
#   'TEAM2': 'TOR',
#   'DATE': '2024-04-10',
#   'PF': 38,
#   'CLUTCH': 64,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.046875},
#  {'GAME_ID': '0022301158',
#   'TEAM1': 'MEM',
#   'TEAM2': 'CLE',
#   'DATE': '2024-04-10',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.1197916666666667},
#  {'GAME_ID': '0022301161',
#   'TEAM1': 'MIA',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-10',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301162',
#   'TEAM1': 'ORL',
#   'TEAM2': 'MIL',
#   'DATE': '2024-04-10',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.59375},
#  {'GAME_ID': '0022301159',
#   'TEAM1': 'CHA',
#   'TEAM2': 'ATL',
#   'DATE': '2024-04-10',
#   'PF': 38,
#   'CLUTCH': 59,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8125},
#  {'GAME_ID': '0022301154',
#   'TEAM1': 'UTA',
#   'TEAM2': 'DEN',
#   'DATE': '2024-04-09',
#   'PF': 19,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9583333333333334},
#  {'GAME_ID': '0022301153',
#   'TEAM1': 'OKC',
#   'TEAM2': 'SAC',
#   'DATE': '2024-04-09',
#   'PF': 40,
#   'CLUTCH': 47,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022301145',
#   'TEAM1': 'PHI',
#   'TEAM2': 'DET',
#   'DATE': '2024-04-09',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301149',
#   'TEAM1': 'CHI',
#   'TEAM2': 'NYK',
#   'DATE': '2024-04-09',
#   'PF': 33,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8177083333333334},
#  {'GAME_ID': '0022301146',
#   'TEAM1': 'TOR',
#   'TEAM2': 'IND',
#   'DATE': '2024-04-09',
#   'PF': 43,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8489583333333334},
#  {'GAME_ID': '0022301150',
#   'TEAM1': 'ORL',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-09',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022301147',
#   'TEAM1': 'ATL',
#   'TEAM2': 'MIA',
#   'DATE': '2024-04-09',
#   'PF': 39,
#   'CLUTCH': 1.0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022301148',
#   'TEAM1': 'MIL',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-09',
#   'PF': 12,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.96875},
#  {'GAME_ID': '0022301152',
#   'TEAM1': 'WAS',
#   'TEAM2': 'MIN',
#   'DATE': '2024-04-09',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.8,
#   'HIGHLIGHTS': 0.9895833333333334},
#  {'GAME_ID': '0022301151',
#   'TEAM1': 'MEM',
#   'TEAM2': 'SAS',
#   'DATE': '2024-04-09',
#   'PF': 25,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9166666666666666},
#  {'GAME_ID': '0022301144',
#   'TEAM1': 'DAL',
#   'TEAM2': 'CHA',
#   'DATE': '2024-04-09',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 1.0052083333333333},
#  {'GAME_ID': '0022301156',
#   'TEAM1': 'PHX',
#   'TEAM2': 'LAC',
#   'DATE': '2024-04-09',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022301155',
#   'TEAM1': 'GSW',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-09',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 1.0729166666666667},
#  {'GAME_ID': '0022301157',
#   'TEAM1': 'NOP',
#   'TEAM2': 'POR',
#   'DATE': '2024-04-09',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022301140',
#   'TEAM1': 'PHI',
#   'TEAM2': 'SAS',
#   'DATE': '2024-04-07',
#   'PF': 37,
#   'CLUTCH': 1.0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9375},
#  {'GAME_ID': '0022301131',
#   'TEAM1': 'HOU',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-07',
#   'PF': 60,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.8541666666666666},
#  {'GAME_ID': '0022301134',
#   'TEAM1': 'BOS',
#   'TEAM2': 'POR',
#   'DATE': '2024-04-07',
#   'PF': 24,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8645833333333334},
#  {'GAME_ID': '0022301133',
#   'TEAM1': 'MIA',
#   'TEAM2': 'IND',
#   'DATE': '2024-04-07',
#   'PF': 46,
#   'CLUTCH': 55,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.453125},
#  {'GAME_ID': '0022301138',
#   'TEAM1': 'NOP',
#   'TEAM2': 'PHX',
#   'DATE': '2024-04-07',
#   'PF': 34,
#   'CLUTCH': 24,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9270833333333334},
#  {'GAME_ID': '0022301142',
#   'TEAM1': 'GSW',
#   'TEAM2': 'UTA',
#   'DATE': '2024-04-07',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.953125},
#  {'GAME_ID': '0022301135',
#   'TEAM1': 'CHA',
#   'TEAM2': 'OKC',
#   'DATE': '2024-04-07',
#   'PF': 31,
#   'CLUTCH': 68,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0260416666666667},
#  {'GAME_ID': '0022301132',
#   'TEAM1': 'CLE',
#   'TEAM2': 'LAC',
#   'DATE': '2024-04-07',
#   'PF': 38,
#   'CLUTCH': 45,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6197916666666666},
#  {'GAME_ID': '0022301141',
#   'TEAM1': 'BKN',
#   'TEAM2': 'SAC',
#   'DATE': '2024-04-07',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301137',
#   'TEAM1': 'WAS',
#   'TEAM2': 'TOR',
#   'DATE': '2024-04-07',
#   'PF': 51,
#   'CLUTCH': 2,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301136',
#   'TEAM1': 'ORL',
#   'TEAM2': 'CHI',
#   'DATE': '2024-04-07',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.640625},
#  {'GAME_ID': '0022301139',
#   'TEAM1': 'MIL',
#   'TEAM2': 'NYK',
#   'DATE': '2024-04-07',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7395833333333334},
#  {'GAME_ID': '0022301143',
#   'TEAM1': 'MIN',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-07',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8229166666666666},
#  {'GAME_ID': '0022301128',
#   'TEAM1': 'DET',
#   'TEAM2': 'BKN',
#   'DATE': '2024-04-06',
#   'PF': 35,
#   'CLUTCH': 38,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022301130',
#   'TEAM1': 'DEN',
#   'TEAM2': 'ATL',
#   'DATE': '2024-04-06',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.921875},
#  {'GAME_ID': '0022301127',
#   'TEAM1': 'LAL',
#   'TEAM2': 'CLE',
#   'DATE': '2024-04-06',
#   'PF': 23,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301129',
#   'TEAM1': 'MEM',
#   'TEAM2': 'PHI',
#   'DATE': '2024-04-06',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022301117',
#   'TEAM1': 'POR',
#   'TEAM2': 'WAS',
#   'DATE': '2024-04-05',
#   'PF': 44,
#   'CLUTCH': 50,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6354166666666666},
#  {'GAME_ID': '0022301116',
#   'TEAM1': 'IND',
#   'TEAM2': 'OKC',
#   'DATE': '2024-04-05',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022301122',
#   'TEAM1': 'TOR',
#   'TEAM2': 'MIL',
#   'DATE': '2024-04-05',
#   'PF': 42,
#   'CLUTCH': 69,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6354166666666666},
#  {'GAME_ID': '0022301119',
#   'TEAM1': 'NYK',
#   'TEAM2': 'CHI',
#   'DATE': '2024-04-05',
#   'PF': 34,
#   'CLUTCH': 6,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.640625},
#  {'GAME_ID': '0022301115',
#   'TEAM1': 'ORL',
#   'TEAM2': 'CHA',
#   'DATE': '2024-04-05',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301118',
#   'TEAM1': 'SAC',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-05',
#   'PF': 26,
#   'CLUTCH': 29,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8072916666666666},
#  {'GAME_ID': '0022301120',
#   'TEAM1': 'MIA',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-05',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7552083333333334},
#  {'GAME_ID': '0022301123',
#   'TEAM1': 'SAS',
#   'TEAM2': 'NOP',
#   'DATE': '2024-04-05',
#   'PF': 30,
#   'CLUTCH': 47,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301125',
#   'TEAM1': 'MIN',
#   'TEAM2': 'PHX',
#   'DATE': '2024-04-05',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6302083333333334},
#  {'GAME_ID': '0022301121',
#   'TEAM1': 'DET',
#   'TEAM2': 'MEM',
#   'DATE': '2024-04-05',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7395833333333334},
#  {'GAME_ID': '0022301097',
#   'TEAM1': 'GSW',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-05',
#   'PF': 36,
#   'CLUTCH': 33,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301126',
#   'TEAM1': 'UTA',
#   'TEAM2': 'LAC',
#   'DATE': '2024-04-05',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.84375},
#  {'GAME_ID': '0022301111',
#   'TEAM1': 'PHI',
#   'TEAM2': 'MIA',
#   'DATE': '2024-04-04',
#   'PF': 25,
#   'CLUTCH': 37,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022301113',
#   'TEAM1': 'HOU',
#   'TEAM2': 'GSW',
#   'DATE': '2024-04-04',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022301114',
#   'TEAM1': 'LAC',
#   'TEAM2': 'DEN',
#   'DATE': '2024-04-04',
#   'PF': 39,
#   'CLUTCH': 55,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.5520833333333334},
#  {'GAME_ID': '0022301124',
#   'TEAM1': 'ATL',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-04',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8385416666666666},
#  {'GAME_ID': '0022301112',
#   'TEAM1': 'SAC',
#   'TEAM2': 'NYK',
#   'DATE': '2024-04-04',
#   'PF': 43,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.65625},
#  {'GAME_ID': '0022301108',
#   'TEAM1': 'MIN',
#   'TEAM2': 'TOR',
#   'DATE': '2024-04-03',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301109',
#   'TEAM1': 'NOP',
#   'TEAM2': 'ORL',
#   'DATE': '2024-04-03',
#   'PF': 46,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.640625},
#  {'GAME_ID': '0022301103',
#   'TEAM1': 'WAS',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-03',
#   'PF': 32,
#   'CLUTCH': 11,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7604166666666666},
#  {'GAME_ID': '0022301105',
#   'TEAM1': 'OKC',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-03',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301102',
#   'TEAM1': 'POR',
#   'TEAM2': 'CHA',
#   'DATE': '2024-04-03',
#   'PF': 34,
#   'CLUTCH': 46,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.4791666666666667},
#  {'GAME_ID': '0022301104',
#   'TEAM1': 'DET',
#   'TEAM2': 'ATL',
#   'DATE': '2024-04-03',
#   'PF': 26,
#   'CLUTCH': 6,
#   'PERFORMANCE': 1.5,
#   'HIGHLIGHTS': 0.859375},
#  {'GAME_ID': '0022301110',
#   'TEAM1': 'CLE',
#   'TEAM2': 'PHX',
#   'DATE': '2024-04-03',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022301106',
#   'TEAM1': 'IND',
#   'TEAM2': 'BKN',
#   'DATE': '2024-04-03',
#   'PF': 37,
#   'CLUTCH': 60,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9479166666666666},
#  {'GAME_ID': '0022301107',
#   'TEAM1': 'MEM',
#   'TEAM2': 'MIL',
#   'DATE': '2024-04-03',
#   'PF': 26,
#   'CLUTCH': 2,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9114583333333334},
#  {'GAME_ID': '0022301100',
#   'TEAM1': 'UTA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-04-02',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.1041666666666667},
#  {'GAME_ID': '0022301101',
#   'TEAM1': 'LAC',
#   'TEAM2': 'SAC',
#   'DATE': '2024-04-02',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.671875},
#  {'GAME_ID': '0022301094',
#   'TEAM1': 'TOR',
#   'TEAM2': 'LAL',
#   'DATE': '2024-04-02',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0208333333333333},
#  {'GAME_ID': '0022301096',
#   'TEAM1': 'MIA',
#   'TEAM2': 'NYK',
#   'DATE': '2024-04-02',
#   'PF': 34,
#   'CLUTCH': 24,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022301095',
#   'TEAM1': 'MIL',
#   'TEAM2': 'WAS',
#   'DATE': '2024-04-02',
#   'PF': 37,
#   'CLUTCH': 30,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6458333333333334},
#  {'GAME_ID': '0022301098',
#   'TEAM1': 'MIN',
#   'TEAM2': 'HOU',
#   'DATE': '2024-04-02',
#   'PF': 40,
#   'CLUTCH': 19,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7239583333333334},
#  {'GAME_ID': '0022300589',
#   'TEAM1': 'GSW',
#   'TEAM2': 'DAL',
#   'DATE': '2024-04-02',
#   'PF': 32,
#   'CLUTCH': 39,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8645833333333334},
#  {'GAME_ID': '0022301099',
#   'TEAM1': 'SAS',
#   'TEAM2': 'DEN',
#   'DATE': '2024-04-02',
#   'PF': 34,
#   'CLUTCH': 63,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 1.125},
#  {'GAME_ID': '0022301093',
#   'TEAM1': 'PHI',
#   'TEAM2': 'OKC',
#   'DATE': '2024-04-02',
#   'PF': 38,
#   'CLUTCH': 71,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8177083333333334},
#  {'GAME_ID': '0022301087',
#   'TEAM1': 'CHA',
#   'TEAM2': 'BOS',
#   'DATE': '2024-04-01',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.75},
#  {'GAME_ID': '0022301092',
#   'TEAM1': 'NOP',
#   'TEAM2': 'PHX',
#   'DATE': '2024-04-01',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.8,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022301089',
#   'TEAM1': 'IND',
#   'TEAM2': 'BKN',
#   'DATE': '2024-04-01',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.859375},
#  {'GAME_ID': '0022301088',
#   'TEAM1': 'DET',
#   'TEAM2': 'MEM',
#   'DATE': '2024-04-01',
#   'PF': 34,
#   'CLUTCH': 46,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.90625},
#  {'GAME_ID': '0022301091',
#   'TEAM1': 'CHI',
#   'TEAM2': 'ATL',
#   'DATE': '2024-04-01',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6979166666666666},
#  {'GAME_ID': '0022301090',
#   'TEAM1': 'POR',
#   'TEAM2': 'ORL',
#   'DATE': '2024-04-01',
#   'PF': 38,
#   'CLUTCH': 33,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6770833333333334},
#  {'GAME_ID': '0022301081',
#   'TEAM1': 'MIA',
#   'TEAM2': 'WAS',
#   'DATE': '2024-03-31',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022301079',
#   'TEAM1': 'CHA',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-31',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9739583333333334},
#  {'GAME_ID': '0022301085',
#   'TEAM1': 'SAS',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-31',
#   'PF': 26,
#   'CLUTCH': 34,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022301078',
#   'TEAM1': 'BKN',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-31',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301086',
#   'TEAM1': 'UTA',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-31',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9583333333333334},
#  {'GAME_ID': '0022301080',
#   'TEAM1': 'PHI',
#   'TEAM2': 'TOR',
#   'DATE': '2024-03-31',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9427083333333334},
#  {'GAME_ID': '0022301082',
#   'TEAM1': 'NYK',
#   'TEAM2': 'OKC',
#   'DATE': '2024-03-31',
#   'PF': 42,
#   'CLUTCH': 79,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301083',
#   'TEAM1': 'HOU',
#   'TEAM2': 'DAL',
#   'DATE': '2024-03-31',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.953125},
#  {'GAME_ID': '0022301077',
#   'TEAM1': 'DEN',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-31',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.828125},
#  {'GAME_ID': '0022301084',
#   'TEAM1': 'CHI',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-31',
#   'PF': 28,
#   'CLUTCH': 41,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7291666666666666},
#  {'GAME_ID': '0022301074',
#   'TEAM1': 'NOP',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-30',
#   'PF': 25,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301075',
#   'TEAM1': 'MEM',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-30',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.96875},
#  {'GAME_ID': '0022301076',
#   'TEAM1': 'MIL',
#   'TEAM2': 'ATL',
#   'DATE': '2024-03-30',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6770833333333334},
#  {'GAME_ID': '0022301064',
#   'TEAM1': 'LAC',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-29',
#   'PF': 28,
#   'CLUTCH': 48,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022301073',
#   'TEAM1': 'SAC',
#   'TEAM2': 'DAL',
#   'DATE': '2024-03-29',
#   'PF': 34,
#   'CLUTCH': 43,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301067',
#   'TEAM1': 'PHI',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-29',
#   'PF': 37,
#   'CLUTCH': 51,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8958333333333334},
#  {'GAME_ID': '0022301072',
#   'TEAM1': 'UTA',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-29',
#   'PF': 41,
#   'CLUTCH': 55,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022301065',
#   'TEAM1': 'DET',
#   'TEAM2': 'WAS',
#   'DATE': '2024-03-29',
#   'PF': 36,
#   'CLUTCH': 16,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.609375},
#  {'GAME_ID': '0022301063',
#   'TEAM1': 'LAL',
#   'TEAM2': 'IND',
#   'DATE': '2024-03-29',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.671875},
#  {'GAME_ID': '0022301068',
#   'TEAM1': 'POR',
#   'TEAM2': 'MIA',
#   'DATE': '2024-03-29',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7604166666666666},
#  {'GAME_ID': '0022301071',
#   'TEAM1': 'DEN',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-29',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6614583333333334},
#  {'GAME_ID': '0022301062',
#   'TEAM1': 'GSW',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-29',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.609375},
#  {'GAME_ID': '0022301070',
#   'TEAM1': 'NYK',
#   'TEAM2': 'SAS',
#   'DATE': '2024-03-29',
#   'PF': 40,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 1.5,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301069',
#   'TEAM1': 'PHX',
#   'TEAM2': 'OKC',
#   'DATE': '2024-03-29',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022301066',
#   'TEAM1': 'CHI',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-29',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301061',
#   'TEAM1': 'NOP',
#   'TEAM2': 'MIL',
#   'DATE': '2024-03-28',
#   'PF': 44,
#   'CLUTCH': 5,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6354166666666666},
#  {'GAME_ID': '0022301060',
#   'TEAM1': 'ATL',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-28',
#   'PF': 32,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022301052',
#   'TEAM1': 'LAC',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-27',
#   'PF': 34,
#   'CLUTCH': 49,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.921875},
#  {'GAME_ID': '0022301055',
#   'TEAM1': 'MEM',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-27',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9635416666666666},
#  {'GAME_ID': '0022301056',
#   'TEAM1': 'MIN',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-27',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5833333333333334},
#  {'GAME_ID': '0022301051',
#   'TEAM1': 'ATL',
#   'TEAM2': 'POR',
#   'DATE': '2024-03-27',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.90625},
#  {'GAME_ID': '0022301050',
#   'TEAM1': 'WAS',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-27',
#   'PF': 37,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022301048',
#   'TEAM1': 'CHA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-27',
#   'PF': 35,
#   'CLUTCH': 32,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7291666666666666},
#  {'GAME_ID': '0022301054',
#   'TEAM1': 'IND',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-27',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022301049',
#   'TEAM1': 'ORL',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-27',
#   'PF': 31,
#   'CLUTCH': 15,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022301057',
#   'TEAM1': 'HOU',
#   'TEAM2': 'OKC',
#   'DATE': '2024-03-27',
#   'PF': 48,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8489583333333334},
#  {'GAME_ID': '0022301059',
#   'TEAM1': 'PHX',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-27',
#   'PF': 26,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8229166666666666},
#  {'GAME_ID': '0022301058',
#   'TEAM1': 'SAS',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-27',
#   'PF': 37,
#   'CLUTCH': 3,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0364583333333333},
#  {'GAME_ID': '0022301053',
#   'TEAM1': 'TOR',
#   'TEAM2': 'NYK',
#   'DATE': '2024-03-27',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9114583333333334},
#  {'GAME_ID': '0022301044',
#   'TEAM1': 'MIA',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-26',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5989583333333334},
#  {'GAME_ID': '0022301046',
#   'TEAM1': 'OKC',
#   'TEAM2': 'NOP',
#   'DATE': '2024-03-26',
#   'PF': 35,
#   'CLUTCH': 43,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022301047',
#   'TEAM1': 'DAL',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-26',
#   'PF': 33,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9322916666666666},
#  {'GAME_ID': '0022301045',
#   'TEAM1': 'MIL',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-26',
#   'PF': 39,
#   'CLUTCH': 1.0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9322916666666666},
#  {'GAME_ID': '0022301043',
#   'TEAM1': 'IND',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-25',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.734375},
#  {'GAME_ID': '0022301037',
#   'TEAM1': 'CHI',
#   'TEAM2': 'WAS',
#   'DATE': '2024-03-25',
#   'PF': 35,
#   'CLUTCH': 77,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8125},
#  {'GAME_ID': '0022301040',
#   'TEAM1': 'DEN',
#   'TEAM2': 'MEM',
#   'DATE': '2024-03-25',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.90625},
#  {'GAME_ID': '0022301036',
#   'TEAM1': 'TOR',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-25',
#   'PF': 31,
#   'CLUTCH': 10,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5104166666666666},
#  {'GAME_ID': '0022301041',
#   'TEAM1': 'DAL',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-25',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0364583333333333},
#  {'GAME_ID': '0022301035',
#   'TEAM1': 'DET',
#   'TEAM2': 'NYK',
#   'DATE': '2024-03-25',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022301033',
#   'TEAM1': 'CHA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-25',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301042',
#   'TEAM1': 'PHI',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-25',
#   'PF': 43,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6614583333333334},
#  {'GAME_ID': '0022301039',
#   'TEAM1': 'SAS',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-25',
#   'PF': 29,
#   'CLUTCH': 39,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.59375},
#  {'GAME_ID': '0022301038',
#   'TEAM1': 'POR',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-25',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6927083333333334},
#  {'GAME_ID': '0022301034',
#   'TEAM1': 'BOS',
#   'TEAM2': 'ATL',
#   'DATE': '2024-03-25',
#   'PF': 34,
#   'CLUTCH': 58,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9947916666666666},
#  {'GAME_ID': '0022301029',
#   'TEAM1': 'MIA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-24',
#   'PF': 33,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6458333333333334},
#  {'GAME_ID': '0022301031',
#   'TEAM1': 'MIN',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-24',
#   'PF': 36,
#   'CLUTCH': 67,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022301028',
#   'TEAM1': 'LAC',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-24',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9791666666666666},
#  {'GAME_ID': '0022301032',
#   'TEAM1': 'IND',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-24',
#   'PF': 45,
#   'CLUTCH': 23,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 1.03125},
#  {'GAME_ID': '0022301027',
#   'TEAM1': 'NOP',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-24',
#   'PF': 47,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022301030',
#   'TEAM1': 'OKC',
#   'TEAM2': 'MIL',
#   'DATE': '2024-03-24',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6197916666666666},
#  {'GAME_ID': '0022301019',
#   'TEAM1': 'NYK',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-23',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022301022',
#   'TEAM1': 'WAS',
#   'TEAM2': 'TOR',
#   'DATE': '2024-03-23',
#   'PF': 38,
#   'CLUTCH': 61,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.796875},
#  {'GAME_ID': '0022301026',
#   'TEAM1': 'POR',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-23',
#   'PF': 41,
#   'CLUTCH': 21,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9270833333333334},
#  {'GAME_ID': '0022301025',
#   'TEAM1': 'SAS',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-23',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7291666666666666},
#  {'GAME_ID': '0022301024',
#   'TEAM1': 'UTA',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-23',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.9479166666666666},
#  {'GAME_ID': '0022301021',
#   'TEAM1': 'ATL',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-23',
#   'PF': 23,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8385416666666666},
#  {'GAME_ID': '0022301020',
#   'TEAM1': 'ORL',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-23',
#   'PF': 39,
#   'CLUTCH': 45,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022301023',
#   'TEAM1': 'BOS',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-23',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022301014',
#   'TEAM1': 'MIN',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-22',
#   'PF': 26,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.640625},
#  {'GAME_ID': '0022301015',
#   'TEAM1': 'SAS',
#   'TEAM2': 'MEM',
#   'DATE': '2024-03-22',
#   'PF': 40,
#   'CLUTCH': 35,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.671875},
#  {'GAME_ID': '0022301012',
#   'TEAM1': 'TOR',
#   'TEAM2': 'OKC',
#   'DATE': '2024-03-22',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7135416666666666},
#  {'GAME_ID': '0022301017',
#   'TEAM1': 'POR',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-22',
#   'PF': 40,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8020833333333334},
#  {'GAME_ID': '0022301018',
#   'TEAM1': 'PHI',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-22',
#   'PF': 39,
#   'CLUTCH': 16,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8125},
#  {'GAME_ID': '0022301011',
#   'TEAM1': 'BOS',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-22',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022301016',
#   'TEAM1': 'GSW',
#   'TEAM2': 'IND',
#   'DATE': '2024-03-22',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.890625},
#  {'GAME_ID': '0022301013',
#   'TEAM1': 'MIA',
#   'TEAM2': 'NOP',
#   'DATE': '2024-03-22',
#   'PF': 22,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.671875},
#  {'GAME_ID': '0022301006',
#   'TEAM1': 'HOU',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-21',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022301008',
#   'TEAM1': 'DAL',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-21',
#   'PF': 43,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8854166666666666},
#  {'GAME_ID': '0022301007',
#   'TEAM1': 'MIL',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-21',
#   'PF': 29,
#   'CLUTCH': 43,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8072916666666666},
#  {'GAME_ID': '0022301009',
#   'TEAM1': 'NYK',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-21',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.6614583333333334},
#  {'GAME_ID': '0022301005',
#   'TEAM1': 'WAS',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-21',
#   'PF': 39,
#   'CLUTCH': 12,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6822916666666666},
#  {'GAME_ID': '0022301004',
#   'TEAM1': 'ORL',
#   'TEAM2': 'NOP',
#   'DATE': '2024-03-21',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022301010',
#   'TEAM1': 'PHX',
#   'TEAM2': 'ATL',
#   'DATE': '2024-03-21',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9479166666666666},
#  {'GAME_ID': '0022301000',
#   'TEAM1': 'OKC',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-20',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8333333333333334},
#  {'GAME_ID': '0022301001',
#   'TEAM1': 'MEM',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-20',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.015625},
#  {'GAME_ID': '0022300996',
#   'TEAM1': 'MIA',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-20',
#   'PF': 39,
#   'CLUTCH': 53,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.625},
#  {'GAME_ID': '0022301003',
#   'TEAM1': 'POR',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-20',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8541666666666666},
#  {'GAME_ID': '0022300999',
#   'TEAM1': 'SAC',
#   'TEAM2': 'TOR',
#   'DATE': '2024-03-20',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.84375},
#  {'GAME_ID': '0022301002',
#   'TEAM1': 'PHX',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-20',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.1875},
#  {'GAME_ID': '0022300998',
#   'TEAM1': 'MIL',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-20',
#   'PF': 43,
#   'CLUTCH': 45,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9010416666666666},
#  {'GAME_ID': '0022300997',
#   'TEAM1': 'IND',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-20',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5416666666666666},
#  {'GAME_ID': '0022300991',
#   'TEAM1': 'CHA',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-19',
#   'PF': 23,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6822916666666666},
#  {'GAME_ID': '0022300993',
#   'TEAM1': 'NOP',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-19',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022300995',
#   'TEAM1': 'DEN',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-19',
#   'PF': 35,
#   'CLUTCH': 36,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6979166666666666},
#  {'GAME_ID': '0022300992',
#   'TEAM1': 'WAS',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-19',
#   'PF': 42,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.875},
#  {'GAME_ID': '0022300994',
#   'TEAM1': 'SAS',
#   'TEAM2': 'DAL',
#   'DATE': '2024-03-19',
#   'PF': 32,
#   'CLUTCH': 46,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9166666666666666},
#  {'GAME_ID': '0022300987',
#   'TEAM1': 'UTA',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-18',
#   'PF': 28,
#   'CLUTCH': 7,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8229166666666666},
#  {'GAME_ID': '0022300984',
#   'TEAM1': 'DET',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-18',
#   'PF': 24,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9010416666666666},
#  {'GAME_ID': '0022300990',
#   'TEAM1': 'LAL',
#   'TEAM2': 'ATL',
#   'DATE': '2024-03-18',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9166666666666666},
#  {'GAME_ID': '0022300985',
#   'TEAM1': 'PHI',
#   'TEAM2': 'MIA',
#   'DATE': '2024-03-18',
#   'PF': 29,
#   'CLUTCH': 38,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022300988',
#   'TEAM1': 'GSW',
#   'TEAM2': 'NYK',
#   'DATE': '2024-03-18',
#   'PF': 33,
#   'CLUTCH': 1,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.75},
#  {'GAME_ID': '0022300986',
#   'TEAM1': 'CHI',
#   'TEAM2': 'POR',
#   'DATE': '2024-03-18',
#   'PF': 45,
#   'CLUTCH': 62,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5885416666666666},
#  {'GAME_ID': '0022300989',
#   'TEAM1': 'SAC',
#   'TEAM2': 'MEM',
#   'DATE': '2024-03-18',
#   'PF': 48,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9791666666666666},
#  {'GAME_ID': '0022300983',
#   'TEAM1': 'IND',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-18',
#   'PF': 42,
#   'CLUTCH': 47,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.515625},
#  {'GAME_ID': '0022300980',
#   'TEAM1': 'WAS',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-17',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9270833333333334},
#  {'GAME_ID': '0022300981',
#   'TEAM1': 'BKN',
#   'TEAM2': 'SAS',
#   'DATE': '2024-03-17',
#   'PF': 37,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.890625},
#  {'GAME_ID': '0022300978',
#   'TEAM1': 'DAL',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-17',
#   'PF': 37,
#   'CLUTCH': 36,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.828125},
#  {'GAME_ID': '0022300982',
#   'TEAM1': 'ATL',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-17',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8541666666666666},
#  {'GAME_ID': '0022300976',
#   'TEAM1': 'PHX',
#   'TEAM2': 'MIL',
#   'DATE': '2024-03-17',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.78125},
#  {'GAME_ID': '0022300977',
#   'TEAM1': 'DET',
#   'TEAM2': 'MIA',
#   'DATE': '2024-03-17',
#   'PF': 30,
#   'CLUTCH': 38,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7395833333333334},
#  {'GAME_ID': '0022300979',
#   'TEAM1': 'TOR',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-17',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5677083333333334},
#  {'GAME_ID': '0022300971',
#   'TEAM1': 'WAS',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-16',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022300974',
#   'TEAM1': 'MIN',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-16',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022300967',
#   'TEAM1': 'HOU',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-16',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.921875},
#  {'GAME_ID': '0022300975',
#   'TEAM1': 'NYK',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-16',
#   'PF': 41,
#   'CLUTCH': 27,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022300969',
#   'TEAM1': 'PHI',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-16',
#   'PF': 44,
#   'CLUTCH': 26,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6927083333333334},
#  {'GAME_ID': '0022300970',
#   'TEAM1': 'NOP',
#   'TEAM2': 'POR',
#   'DATE': '2024-03-16',
#   'PF': 28,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8072916666666666},
#  {'GAME_ID': '0022300972',
#   'TEAM1': 'OKC',
#   'TEAM2': 'MEM',
#   'DATE': '2024-03-16',
#   'PF': 39,
#   'CLUTCH': 15,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8645833333333334},
#  {'GAME_ID': '0022300973',
#   'TEAM1': 'GSW',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-16',
#   'PF': 32,
#   'CLUTCH': 1,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8645833333333334},
#  {'GAME_ID': '0022300968',
#   'TEAM1': 'IND',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-16',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6041666666666666},
#  {'GAME_ID': '0022300961',
#   'TEAM1': 'CHA',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-15',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.515625},
#  {'GAME_ID': '0022300966',
#   'TEAM1': 'ATL',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-15',
#   'PF': 37,
#   'CLUTCH': 21,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0104166666666667},
#  {'GAME_ID': '0022300963',
#   'TEAM1': 'TOR',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-15',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8125},
#  {'GAME_ID': '0022300962',
#   'TEAM1': 'MIA',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-15',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6822916666666666},
#  {'GAME_ID': '0022300965',
#   'TEAM1': 'SAS',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-15',
#   'PF': 33,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7239583333333334},
#  {'GAME_ID': '0022300964',
#   'TEAM1': 'NOP',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-15',
#   'PF': 38,
#   'CLUTCH': 21,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7447916666666666},
#  {'GAME_ID': '0022300956',
#   'TEAM1': 'LAC',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-14',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022300957',
#   'TEAM1': 'WAS',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-14',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6666666666666666},
#  {'GAME_ID': '0022300959',
#   'TEAM1': 'DAL',
#   'TEAM2': 'OKC',
#   'DATE': '2024-03-14',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022300960',
#   'TEAM1': 'POR',
#   'TEAM2': 'NYK',
#   'DATE': '2024-03-14',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.453125},
#  {'GAME_ID': '0022300958',
#   'TEAM1': 'MIL',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-14',
#   'PF': 32,
#   'CLUTCH': 27,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022300955',
#   'TEAM1': 'PHX',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-14',
#   'PF': 25,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022300953',
#   'TEAM1': 'ATL',
#   'TEAM2': 'POR',
#   'DATE': '2024-03-13',
#   'PF': 44,
#   'CLUTCH': 67,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022300951',
#   'TEAM1': 'CLE',
#   'TEAM2': 'NOP',
#   'DATE': '2024-03-13',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7916666666666666},
#  {'GAME_ID': '0022300947',
#   'TEAM1': 'BKN',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-13',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022300946',
#   'TEAM1': 'DET',
#   'TEAM2': 'TOR',
#   'DATE': '2024-03-13',
#   'PF': 41,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8958333333333334},
#  {'GAME_ID': '0022300954',
#   'TEAM1': 'SAC',
#   'TEAM2': 'LAL',
#   'DATE': '2024-03-13',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022300948',
#   'TEAM1': 'IND',
#   'TEAM2': 'CHI',
#   'DATE': '2024-03-13',
#   'PF': 46,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7291666666666666},
#  {'GAME_ID': '0022300950',
#   'TEAM1': 'MEM',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-13',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.953125},
#  {'GAME_ID': '0022300949',
#   'TEAM1': 'MIA',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-13',
#   'PF': 26,
#   'CLUTCH': 1,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.4583333333333333},
#  {'GAME_ID': '0022300952',
#   'TEAM1': 'GSW',
#   'TEAM2': 'DAL',
#   'DATE': '2024-03-13',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9427083333333334},
#  {'GAME_ID': '0022300944',
#   'TEAM1': 'MIN',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-12',
#   'PF': 38,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6510416666666666},
#  {'GAME_ID': '0022300941',
#   'TEAM1': 'OKC',
#   'TEAM2': 'IND',
#   'DATE': '2024-03-12',
#   'PF': 27,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022300945',
#   'TEAM1': 'MIL',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-12',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7239583333333334},
#  {'GAME_ID': '0022300940',
#   'TEAM1': 'MEM',
#   'TEAM2': 'WAS',
#   'DATE': '2024-03-12',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.734375},
#  {'GAME_ID': '0022300943',
#   'TEAM1': 'BOS',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-12',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0052083333333333},
#  {'GAME_ID': '0022300942',
#   'TEAM1': 'SAS',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-12',
#   'PF': 39,
#   'CLUTCH': 50,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.765625},
#  {'GAME_ID': '0022300939',
#   'TEAM1': 'NYK',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-12',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.71875},
#  {'GAME_ID': '0022300938',
#   'TEAM1': 'POR',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-11',
#   'PF': 22,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9322916666666666},
#  {'GAME_ID': '0022300937',
#   'TEAM1': 'TOR',
#   'TEAM2': 'DEN',
#   'DATE': '2024-03-11',
#   'PF': 30,
#   'CLUTCH': 31,
#   'PERFORMANCE': 0.8,
#   'HIGHLIGHTS': 0.7864583333333334},
#  {'GAME_ID': '0022300936',
#   'TEAM1': 'GSW',
#   'TEAM2': 'SAS',
#   'DATE': '2024-03-11',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.90625},
#  {'GAME_ID': '0022300933',
#   'TEAM1': 'DET',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-11',
#   'PF': 35,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7760416666666666},
#  {'GAME_ID': '0022300934',
#   'TEAM1': 'CLE',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-11',
#   'PF': 36,
#   'CLUTCH': 45,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8177083333333334},
#  {'GAME_ID': '0022300935',
#   'TEAM1': 'CHI',
#   'TEAM2': 'DAL',
#   'DATE': '2024-03-11',
#   'PF': 29,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7083333333333334},
#  {'GAME_ID': '0022300932',
#   'TEAM1': 'LAL',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-10',
#   'PF': 30,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.84375},
#  {'GAME_ID': '0022300924',
#   'TEAM1': 'MIL',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-10',
#   'PF': 38,
#   'CLUTCH': 22,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.921875},
#  {'GAME_ID': '0022300928',
#   'TEAM1': 'IND',
#   'TEAM2': 'ORL',
#   'DATE': '2024-03-10',
#   'PF': 48,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.703125},
#  {'GAME_ID': '0022300930',
#   'TEAM1': 'BKN',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-10',
#   'PF': 34,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9583333333333334},
#  {'GAME_ID': '0022300925',
#   'TEAM1': 'ATL',
#   'TEAM2': 'NOP',
#   'DATE': '2024-03-10',
#   'PF': 25,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.0260416666666667},
#  {'GAME_ID': '0022300927',
#   'TEAM1': 'NYK',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-10',
#   'PF': 32,
#   'CLUTCH': 20,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6354166666666666},
#  {'GAME_ID': '0022300929',
#   'TEAM1': 'SAC',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-10',
#   'PF': 38,
#   'CLUTCH': 3,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.5520833333333334},
#  {'GAME_ID': '0022300931',
#   'TEAM1': 'OKC',
#   'TEAM2': 'MEM',
#   'DATE': '2024-03-10',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.9583333333333334},
#  {'GAME_ID': '0022300926',
#   'TEAM1': 'MIA',
#   'TEAM2': 'WAS',
#   'DATE': '2024-03-10',
#   'PF': 36,
#   'CLUTCH': 31,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.84375},
#  {'GAME_ID': '0022300922',
#   'TEAM1': 'DEN',
#   'TEAM2': 'UTA',
#   'DATE': '2024-03-09',
#   'PF': 37,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.9010416666666666},
#  {'GAME_ID': '0022300920',
#   'TEAM1': 'BOS',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-09',
#   'PF': 26,
#   'CLUTCH': 17,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.75},
#  {'GAME_ID': '0022300918',
#   'TEAM1': 'CHA',
#   'TEAM2': 'BKN',
#   'DATE': '2024-03-09',
#   'PF': 32,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6614583333333334},
#  {'GAME_ID': '0022300921',
#   'TEAM1': 'SAS',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-09',
#   'PF': 46,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8802083333333334},
#  {'GAME_ID': '0022300919',
#   'TEAM1': 'DAL',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-09',
#   'PF': 44,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.984375},
#  {'GAME_ID': '0022300923',
#   'TEAM1': 'TOR',
#   'TEAM2': 'POR',
#   'DATE': '2024-03-09',
#   'PF': 36,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8958333333333334},
#  {'GAME_ID': '0022300917',
#   'TEAM1': 'CHI',
#   'TEAM2': 'LAC',
#   'DATE': '2024-03-09',
#   'PF': 39,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022300912',
#   'TEAM1': 'ORL',
#   'TEAM2': 'NYK',
#   'DATE': '2024-03-08',
#   'PF': 26,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8645833333333334},
#  {'GAME_ID': '0022300915',
#   'TEAM1': 'LAL',
#   'TEAM2': 'MIL',
#   'DATE': '2024-03-08',
#   'PF': 33,
#   'CLUTCH': 54,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.875},
#  {'GAME_ID': '0022300913',
#   'TEAM1': 'MEM',
#   'TEAM2': 'ATL',
#   'DATE': '2024-03-08',
#   'PF': 39,
#   'CLUTCH': 46,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022300909',
#   'TEAM1': 'NOP',
#   'TEAM2': 'PHI',
#   'DATE': '2024-03-08',
#   'PF': 37,
#   'CLUTCH': 1,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.7708333333333334},
#  {'GAME_ID': '0022300910',
#   'TEAM1': 'WAS',
#   'TEAM2': 'CHA',
#   'DATE': '2024-03-08',
#   'PF': 39,
#   'CLUTCH': 7,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.796875},
#  {'GAME_ID': '0022300916',
#   'TEAM1': 'POR',
#   'TEAM2': 'HOU',
#   'DATE': '2024-03-08',
#   'PF': 31,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 1.03125},
#  {'GAME_ID': '0022300914',
#   'TEAM1': 'OKC',
#   'TEAM2': 'MIA',
#   'DATE': '2024-03-08',
#   'PF': 32,
#   'CLUTCH': 22,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.7552083333333334},
#  {'GAME_ID': '0022300911',
#   'TEAM1': 'MIN',
#   'TEAM2': 'CLE',
#   'DATE': '2024-03-08',
#   'PF': 45,
#   'CLUTCH': 0.95,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8177083333333334},
#  {'GAME_ID': '0022300903',
#   'TEAM1': 'IND',
#   'TEAM2': 'MIN',
#   'DATE': '2024-03-07',
#   'PF': 44,
#   'CLUTCH': 55,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.828125},
#  {'GAME_ID': '0022300907',
#   'TEAM1': 'CHI',
#   'TEAM2': 'GSW',
#   'DATE': '2024-03-07',
#   'PF': 44,
#   'CLUTCH': 48,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.6927083333333334},
#  {'GAME_ID': '0022300905',
#   'TEAM1': 'TOR',
#   'TEAM2': 'PHX',
#   'DATE': '2024-03-07',
#   'PF': 36,
#   'CLUTCH': 0,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8177083333333334},
#  {'GAME_ID': '0022300906',
#   'TEAM1': 'DEN',
#   'TEAM2': 'BOS',
#   'DATE': '2024-03-07',
#   'PF': 37,
#   'CLUTCH': 25,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.671875},
#  {'GAME_ID': '0022300902',
#   'TEAM1': 'BKN',
#   'TEAM2': 'DET',
#   'DATE': '2024-03-07',
#   'PF': 35,
#   'CLUTCH': 9,
#   'PERFORMANCE': 0.0,
#   'HIGHLIGHTS': 0.8697916666666666},
#  {'GAME_ID': '0022300904',
#   'TEAM1': 'DAL',
#   'TEAM2': 'MIA',
#   'DATE': '2024-03-07',
#   'PF': 36,
#   'CLUTCH': 36,
#   'PERFORMANCE': 0.7,
#   'HIGHLIGHTS': 0.8489583333333334},
#  {'GAME_ID': '0022300908',
#   'TEAM1': 'SAS',
#   'TEAM2': 'SAC',
#   'DATE': '2024-03-07',
#   'PF': 35,
#   'CLUTCH': 56,
#   'PERFORMANCE': 1.4,
#   'HIGHLIGHTS': 0.8020833333333334}]
